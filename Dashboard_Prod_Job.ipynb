# %% [markdown]
# # <div style="text-align: center">HROS Production Runtimes Dashboard</div>

# %%
# !pip install pandas

# !pip install numpy

# !pip install ipywidgets
# !jupyter nbextension enable --py widgetsnbextension

# !pip install plotly

# !pip install jupyter_dashboards
# !jupyter nbextension install --py jupyter_dashboards --sys-prefix
# !jupyter nbextension enable --py jupyter_dashboards --sys-prefix
# !pip install termcolor
# !pip install xlrd
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: pytz>=2017.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.18.1)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: ipywidgets in /srv/conda/envs/notebook/lib/python3.7/site-packages (7.5.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets) (7.11.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets) (5.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets) (5.1.4)
# Requirement already satisfied: traitlets>=4.3.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets) (4.3.3)
# Requirement already satisfied: setuptools>=18.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (45.1.0.post20200119)
# Requirement already satisfied: pygments in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.5.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (3.0.3)
# Requirement already satisfied: jedi>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.16.0)
# Requirement already satisfied: backcall in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.0)
# Requirement already satisfied: pickleshare in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.8.0)
# Requirement already satisfied: decorator in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.4.1)
# Requirement already satisfied: notebook>=4.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.0.3)
# Requirement already satisfied: ipython-genutils in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jupyter-core in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.6.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: jupyter-client in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.4)
# Requirement already satisfied: tornado>=4.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.3)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from traitlets>=4.3.1->ipywidgets) (1.14.0)
# Requirement already satisfied: wcwidth in /srv/conda/envs/notebook/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.8)
# Requirement already satisfied: parso>=0.5.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.6.0)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.6.0)
# Requirement already satisfied: terminado>=0.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.0)
# Requirement already satisfied: nbconvert in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (5.6.1)
# Requirement already satisfied: pyzmq>=17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (18.1.1)
# Requirement already satisfied: Send2Trash in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: prometheus-client in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.15.7)
# Requirement already satisfied: attrs>=17.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: bleach in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.1.0)
# Requirement already satisfied: defusedxml in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.2)
# Requirement already satisfied: testpath in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4.4)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (2.1.0)
# Requirement already satisfied: webencodings in /srv/conda/envs/notebook/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: plotly in /srv/conda/envs/notebook/lib/python3.7/site-packages (4.5.2)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from plotly) (1.14.0)
# Requirement already satisfied: retrying>=1.3.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from plotly) (1.3.3)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: jupyter_dashboards in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.7.0)
# Requirement already satisfied: notebook>=4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter_dashboards) (6.0.3)
# Requirement already satisfied: Send2Trash in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (18.1.1)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (2.11.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (5.3.4)
# Requirement already satisfied: prometheus-client in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (0.7.1)
# Requirement already satisfied: ipykernel in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (5.1.4)
# Requirement already satisfied: traitlets>=4.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (4.3.3)
# Requirement already satisfied: jupyter-core>=4.6.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (4.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (0.8.3)
# Requirement already satisfied: tornado>=5.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (6.0.3)
# Requirement already satisfied: nbformat in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (5.0.4)
# Requirement already satisfied: nbconvert in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (5.6.1)
# Requirement already satisfied: ipython-genutils in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.0->jupyter_dashboards) (0.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jinja2->notebook>=4.0->jupyter_dashboards) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_dashboards) (2.8.1)
# Requirement already satisfied: ipython>=5.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipykernel->notebook>=4.0->jupyter_dashboards) (7.11.1)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from traitlets>=4.2.1->notebook>=4.0->jupyter_dashboards) (1.14.0)
# Requirement already satisfied: decorator in /srv/conda/envs/notebook/lib/python3.7/site-packages (from traitlets>=4.2.1->notebook>=4.0->jupyter_dashboards) (4.4.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbformat->notebook>=4.0->jupyter_dashboards) (3.2.0)
# Requirement already satisfied: defusedxml in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.6.0)
# Requirement already satisfied: testpath in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.4.4)
# Requirement already satisfied: bleach in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (3.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.3)
# Requirement already satisfied: pygments in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (2.5.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (1.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (3.0.3)
# Requirement already satisfied: jedi>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.16.0)
# Requirement already satisfied: backcall in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.1.0)
# Requirement already satisfied: pickleshare in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (45.1.0.post20200119)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (4.8.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_dashboards) (0.15.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_dashboards) (1.5.0)
# Requirement already satisfied: attrs>=17.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_dashboards) (19.3.0)
# Requirement already satisfied: webencodings in /srv/conda/envs/notebook/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.0->jupyter_dashboards) (0.5.1)
# Requirement already satisfied: wcwidth in /srv/conda/envs/notebook/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.1.8)
# Requirement already satisfied: parso>=0.5.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.6.0)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.6.0)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_dashboards) (2.1.0)
# Installing /srv/conda/envs/notebook/lib/python3.7/site-packages/jupyter_dashboards/nbextension -> jupyter_dashboards
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/main.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/link-css.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-common/error-log.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-common/gridstack-overrides.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-common/gridstack-custom.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-common/dashboard-common.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/sub-menu.html
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/template-loader.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/polymer-support.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/dashboard-actions.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/dashboard-metadata.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/dashboard-view.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/dashboard-metadata-compatibility.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/notebook-util.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/help.html
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/dashboard-view.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/view-toolbar-buttons.html
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/dashboard-actions.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/object-util.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/view-menu.html
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/layout/report/cell-controls.html
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/layout/report/layout.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/layout/report/layout.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/layout/report/collapse-button.html
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/layout/grid/cell-controls.html
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/layout/grid/layout.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/dashboard-view/layout/grid/layout.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/.bower.json
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/README.md
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/bower.json
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/LICENSE.txt
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/AUTHORS.txt
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/offset.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/serialize.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/traversing.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/jquery.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/dimensions.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/data.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/ajax.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/attributes.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/deferred.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/queue.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/selector-native.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/deprecated.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/effects.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/selector-sizzle.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/wrap.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/selector.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/.eslintrc.json
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/manipulation.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/callbacks.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/event.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/manipulation/wrapMap.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/manipulation/getAll.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/manipulation/_evalUrl.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/manipulation/support.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/manipulation/buildFragment.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/manipulation/setGlobalEval.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/manipulation/var/rcheckableType.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/manipulation/var/rscriptType.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/manipulation/var/rtagName.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/queue/delay.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/traversing/findFilter.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/traversing/var/siblings.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/traversing/var/dir.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/traversing/var/rneedsContext.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/deferred/exceptionHook.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/adjustCSS.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/showHide.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/curCSS.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/support.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/addGetHookIf.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/hiddenVisibleSelectors.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/var/rmargin.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/var/swap.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/var/isHiddenWithinTree.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/var/getStyles.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/var/cssExpand.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/css/var/rnumnonpx.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/hasOwn.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/getProto.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/rnothtmlwhite.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/toString.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/indexOf.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/fnToString.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/arr.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/support.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/concat.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/push.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/slice.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/document.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/rcssNum.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/class2type.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/documentElement.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/ObjectFunctionString.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/var/pnum.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/exports/amd.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/exports/global.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/attributes/attr.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/attributes/val.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/attributes/support.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/attributes/prop.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/attributes/classes.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core/nodeName.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core/support.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core/init.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core/access.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core/ready-no-deferred.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core/readyException.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core/stripAndCollapse.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core/DOMEval.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core/ready.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core/parseHTML.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/core/var/rsingleTag.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/ajax/xhr.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/ajax/load.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/ajax/script.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/ajax/jsonp.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/ajax/parseXML.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/ajax/var/nonce.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/ajax/var/rquery.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/ajax/var/location.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/event/alias.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/event/focusin.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/event/support.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/event/ajax.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/event/trigger.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/effects/Tween.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/effects/animatedSelector.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/data/Data.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/data/var/dataUser.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/data/var/acceptData.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/src/data/var/dataPriv.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/external/sizzle/LICENSE.txt
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/external/sizzle/dist/sizzle.min.map
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/external/sizzle/dist/sizzle.min.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/external/sizzle/dist/sizzle.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/dist/jquery.slim.min.map
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/dist/jquery.slim.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/dist/jquery.min.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/dist/jquery.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/dist/core.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/dist/jquery.slim.min.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery/dist/jquery.min.map
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/.bower.json
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/README.md
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/package.json
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/LICENSE
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/bower.json
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs-text/text.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/yarn.lock
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/.jscsrc
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/.editorconfig
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/.bower.json
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/README.md
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/package.json
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/LICENSE
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/.travis.yml
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/CHANGELOG
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/.markdown-doctest-setup.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/.gitattributes
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/.gitignore
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lodash.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/common/minify.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/common/util.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/common/file.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/common/mapping.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/common/uglify.options.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/main/build-site.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/main/build-modules.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/main/build-dist.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/main/build-doc.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/build-modules.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/build-dist.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/build-doc.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/template/doc/wiki.jst
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/template/modules/fp.jst
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/template/modules/_falseOptions.jst
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/template/modules/_util.jst
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/template/modules/module.jst
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/template/modules/category.jst
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/template/modules/thru.jst
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/template/modules/convert.jst
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/lib/fp/template/modules/alias.jst
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/doc/README.md
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/perf/perf.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/perf/index.html
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/perf/asset/perf-ui.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/.github/CONTRIBUTING.md
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/backbone/LICENSE
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/backbone/backbone.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/backbone/test/model.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/backbone/test/collection.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/backbone/test/sync.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/backbone/test/router.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/backbone/test/events.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/backbone/test/view.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/backbone/test/noconflict.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/backbone/test/setup/environment.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/backbone/test/setup/dom-setup.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/underscore/LICENSE
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/underscore/underscore-min.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/underscore/underscore.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/underscore/test/objects.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/underscore/test/arrays.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/underscore/test/functions.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/underscore/test/cross-document.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/underscore/test/collections.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/underscore/test/chaining.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/underscore/test/utility.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/license.txt
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/src/firebug-lite-debug.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/skin/xp/up.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/skin/xp/errorIcon.gif
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/skin/xp/pixel_transparent.gif
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/skin/xp/shadowAlpha.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/skin/xp/down.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/skin/xp/tabHoverRight.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/skin/xp/textEditorCorners.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/skin/xp/blank.gif
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/skin/xp/disableHover.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/lodash/vendor/firebug-lite/skin/xp/firebug.png
# ...
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/flick/jquery-ui.min.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/flick/images/ui-bg_glass_65_ffffff_1x400.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/flick/images/ui-icons_666666_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/flick/images/ui-icons_ffffff_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/flick/images/ui-icons_ff0084_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/flick/images/ui-bg_highlight-soft_100_f6f6f6_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/flick/images/ui-bg_highlight-soft_25_0073ea_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/flick/images/ui-icons_0073ea_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/flick/images/ui-icons_454545_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/flick/images/ui-bg_highlight-soft_50_dddddd_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/theme.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/jquery-ui.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/jquery-ui.min.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/images/ui-icons_ffffff_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/images/ui-bg_diagonals-thick_75_f3d8d8_40x40.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/images/ui-bg_highlight-hard_100_f6f6f6_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/images/ui-icons_cc0000_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/images/ui-bg_glass_55_fbf8ee_1x400.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/images/ui-icons_004276_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/images/ui-bg_highlight-hard_100_eeeeee_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/images/ui-bg_dots-small_65_a6a6a6_2x2.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/blitzer/images/ui-bg_highlight-soft_15_cc0000_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/theme.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/jquery-ui.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/jquery-ui.min.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-icons_ffffff_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-icons_2694e8_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-bg_glass_80_d7ebf9_1x400.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-bg_highlight-soft_100_deedf7_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-icons_3d80b3_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-bg_highlight-hard_70_000000_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-bg_glass_50_3baae3_1x400.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-icons_2e83ff_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-bg_glass_100_e4f1fb_1x400.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-bg_diagonals-thick_90_eeeeee_40x40.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-bg_highlight-soft_25_ffef8f_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-icons_72a7cf_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/cupertino/images/ui-bg_highlight-hard_100_f2f5f7_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/theme.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/jquery-ui.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/jquery-ui.min.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/images/ui-bg_gloss-wave_30_3d3644_500x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/images/ui-icons_ebccce_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/images/ui-bg_highlight-soft_100_dcd9de_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/images/ui-icons_ffffff_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/images/ui-icons_734d99_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/images/ui-bg_highlight-soft_25_30273a_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/images/ui-icons_8d78a5_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/images/ui-bg_highlight-soft_100_eae6ea_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/images/ui-icons_454545_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/images/ui-icons_a8a3ae_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/eggplant/images/ui-bg_highlight-soft_45_5f5964_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/theme.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/jquery-ui.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/jquery-ui.min.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-icons_4eb305_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-bg_highlight-hard_30_285c00_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-icons_ffffff_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-bg_diagonals-small_0_aaaaaa_40x40.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-icons_72b42d_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-icons_cd0a0a_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-bg_diagonals-thick_95_ffdc2e_40x40.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-bg_glass_55_fbf5d0_1x400.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-bg_highlight-soft_60_4ca20b_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-bg_inset-soft_10_285c00_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-bg_diagonals-thick_15_444444_40x40.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-bg_highlight-soft_50_4eb305_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/le-frog/images/ui-bg_highlight-soft_33_3a8104_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/theme.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/jquery-ui.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/jquery-ui.min.css
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-bg_gloss-wave_30_44372c_500x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-bg_gloss-wave_20_1c160d_500x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-icons_ffffff_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-bg_glass_15_5f391b_1x400.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-bg_highlight-soft_20_619226_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-icons_e3ddc9_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-icons_222222_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-icons_add978_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-bg_inset-soft_10_201913_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-icons_9bcc60_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-bg_highlight-soft_20_201913_1x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-bg_gloss-wave_25_453326_500x100.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/jquery-ui/themes/mint-choc/images/ui-icons_f1fd86_256x240.png
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs/.bower.json
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs/README.md
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs/require.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/jupyter_dashboards/notebook/bower_components/requirejs/bower.json
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable jupyter_dashboards --py --sys-prefix
# Enabling notebook extension jupyter_dashboards/notebook/main...
#       - Validating: OK
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: termcolor in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.1.0)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: xlrd in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.2.0)

# %%
import pandas as pd
import numpy as np
from ipywidgets import interact
from IPython.display import display
import plotly.graph_objects as go
import ipywidgets as widgets
import datetime
import warnings
warnings.filterwarnings("ignore")
from datetime import date, timedelta
import plotly.express as px
from plotly.subplots import make_subplots
#import chart_studio.plotly as py
from termcolor import colored,cprint

#location = "C:\\Users\\Shubham.k\\Downloads\\RDP DI - Dashboard"

# %%
df1 = pd.read_excel('test_2.xlsx') # Overall level data
df2 = pd.read_excel('test.xlsx') # daily level data

# %%
df_cleaned = df1[df1['Activation']<'2020-01-23']

Last_refresh_dt = max(pd.to_datetime(df2['End']))

# %%
df_cleaned['Activation'] = pd.to_datetime(df_cleaned['Activation']).dt.strftime('%d-%b-%y')
df_cleaned['Start time'] = pd.to_datetime(df_cleaned['Start time'])
df_cleaned['End'] = pd.to_datetime(df_cleaned['End'])

# %%
df_cleaned.reset_index(inplace=True)

# %%
def convert(seconds,flag):
    if flag == 0:
        seconds = seconds % (24 * 3600) 
        hour = seconds // 3600
        seconds %= 3600
        minutes = seconds // 60
        seconds %= 60
        return "%02d.%02d" % (hour, minutes)
    elif flag == 1:
        return "%02d:%02d" % (hour, minutes)

# %%
df_cleaned['start_time'] = df_cleaned['Start time'].dt.date
#df1['end_time'] = df1['End'].dt.date
l = list()

for i in range(len(df_cleaned)):
    s = str(df_cleaned['start_time'][i]) + " 00:00:00"
    l.append(s)

df_cleaned['start_time'] = l
df_cleaned['start_time'] = pd.to_datetime(df_cleaned['start_time'])


df_cleaned['end_time'] = df_cleaned['End'].dt.date
#df1['end_time'] = df1['End'].dt.date
l = list()

for i in range(len(df_cleaned)):
    s = str(df_cleaned['end_time'][i]) + " 00:00:00"
    l.append(s)

df_cleaned['end_time'] = l
df_cleaned['end_time'] = pd.to_datetime(df_cleaned['end_time'])

# %%
l = list()

for i in range(len(df_cleaned)):
    t = convert(pd.Timedelta(df_cleaned['Start time'][i] - df_cleaned['start_time'][i]).seconds,0)
    l.append(float(t))
    
df_cleaned['start_td'] = l
df_cleaned['start_td'] = df_cleaned['start_td'].round(2)

###############################################################################################

l = list()

for i in range(len(df_cleaned)):
    t = convert(pd.Timedelta(df_cleaned['End'][i] - df_cleaned['end_time'][i]).seconds,0)
    l.append(float(t))
    
df_cleaned['end_td'] = l
df_cleaned['end_td'] = df_cleaned['end_td'].round(2)

# %%
l1 = list()
l2 = list()

for i in range(len(df_cleaned)):
    t1 = convert(pd.Timedelta(df_cleaned['End'][i] - df_cleaned['Start time'][i]).seconds,0)
    t2 = pd.Timedelta(df_cleaned['End'][i] - df_cleaned['Start time'][i]).seconds
    l1.append(t1)
    l2.append(t2)
    
df_cleaned['time_diff'] = l1
df_cleaned['time_diff_cal'] = l2
df_cleaned['time_diff_cal'] = df_cleaned['time_diff_cal'].round(2)

# %%
df_cleaned = df_cleaned[['Activation','Start time','End','start_td','end_td','time_diff','time_diff_cal']]

# %%
print (colored('                                                                        Last Refresh Datetime : ',attrs=['bold'])+colored(Last_refresh_dt, 'blue',attrs=['bold']))
# Out:
#                                                                         Last Refresh Datetime : 2020-02-11 05:37:37

# %%
def graph1(df_n):
    df_n['Activation'] = df_n['Activation'].astype('datetime64')
    df_n.sort_values(by= 'Activation',inplace=True,ascending=True)
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df_n['Activation'], y=df_n['time_diff'],
        line=dict(width=2.0, color='rgb(131, 90, 241)'),#rgb(255, 127, 14)
        name = 'Runtime',
        mode='lines+markers'
        ))
         
    fig.add_trace(go.Scatter(
        x=df_n['Activation'], y=df_n['avg_line'],
        line=dict(width=2.0, color='rgb(34, 178, 159)',dash='dot'),#rgb(255, 127, 14)
        name = 'Avg. Runtime',
        mode='lines'
        )),

    fig.update_layout(
    xaxis_title="Load Date",
    yaxis_title="Runtime (in hr.min)",
    
    titlefont=dict(
        size=20
        ),
        title={
        'text': "Daily Trend of Production Jobs Runtime",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
         xaxis=dict(showticklabels=True, automargin=True)
    )
    fig.show()

# %%
def plot1(Date_Range):
    df_n = pd.DataFrame()
    if (Date_Range == 'Last 1 Week'):
        df_n=df_cleaned[df_cleaned['Start time']>np.max(df_cleaned['Start time'])-timedelta(7)]
        df_n['avg_line'] = convert(df_n['time_diff_cal'].mean(),0)
        graph1(df_n)
    elif(Date_Range == 'Last 2 Week'):    
        df_n=df_cleaned[df_cleaned['Start time']>np.max(df_cleaned['Start time'])-timedelta(14)]
        df_n['avg_line'] = convert(df_n['time_diff_cal'].mean(),0)
        graph1(df_n)
    elif(Date_Range == 'Last 3 Week'):
        df_n=df_cleaned[df_cleaned['Start time']>np.max(df_cleaned['Start time'])-timedelta(21)]
        df_n['avg_line'] = convert(df_n['time_diff_cal'].mean(),0)
        graph1(df_n)
    elif(Date_Range == 'Last 4 Week'):
        df_n=df_cleaned[df_cleaned['Start time']>np.max(df_cleaned['Start time'])-timedelta(28)]
        df_n['avg_line'] = convert(df_n['time_diff_cal'].mean(),0)
        graph1(df_n)

        
widgets.interact(plot1,Date_Range=['Last 4 Week','Last 3 Week','Last 2 Week','Last 1 Week']);
# Out:
# interactive(children=(Dropdown(description='Date_Range', options=('Last 4 Week', 'Last 3 Week', 'Last 2 Week',…

# %%
# Production Jobs Trigger (Weekly)

# %%
df3 = pd.read_excel('Cleaned_data.xlsx')
df3 = df3[df3['trigger']!='other'].reset_index()
df3['Activation_x'] = pd.to_datetime(df3['Activation_x']).dt.strftime('%d-%b-%y')
df3['Start time_x'] = pd.to_datetime(df3['Start time_x'])
df3['End_x'] = pd.to_datetime(df3['End_x'])

# %%
df_cleaned3 = df3.groupby(['trigger','Activation_x']).agg({'Start time_x': 'min', 'End_x': 'max'}).reset_index()
#df_cleaned3= df3.groupby(['Activation_y','trigger','Start time_y','End_y'])['TableName'].count().reset_index(name='count')

# %%
l1 = list()
l2 = list()

for i in range(len(df_cleaned3)):
    t1 = convert(pd.Timedelta(df_cleaned3['End_x'][i] - df_cleaned3['Start time_x'][i]).seconds,0)
    t2 = pd.Timedelta(df_cleaned3['End_x'][i] - df_cleaned3['Start time_x'][i]).seconds
    l1.append(t1)
    l2.append(t2)
    
df_cleaned3['time_diff'] = l1
df_cleaned3['time_diff_cal'] = l2
df_cleaned3['time_diff_cal'] = df_cleaned3['time_diff_cal'].round(2)

# %% [markdown]
# # <div style="text-align: center"> II. Trigger Level Runtimes </div>

# %%
def graph2(df_cleaned3):
    fig = make_subplots(rows=4,
                    cols=1,
                    y_title='Run Time (in hr.min)',
                    subplot_titles=('Trigger 1 Daily Runtimes',  'Trigger 2 Daily Runtimes', 
                                    'Trigger 3 Daily Runtimes', 'Trigger 4 Daily Runtimes'))

   
    df_cleaned3['Activation_x'] = df_cleaned3['Activation_x'].astype('datetime64')
    br1 = df_cleaned3[df_cleaned3['trigger']=='trigger1'].reset_index()
    br1['avg_line'] = convert(br1['time_diff_cal'].mean(),0)
    br1.sort_values(by= 'Activation_x',inplace=True,ascending=True)

    fig.add_trace(go.Scatter(
        x=br1['Activation_x'], y=br1['time_diff'],
        line=dict(width=2.0, color='rgb(15, 89, 146)'),
        name = 'Exec Time',
        mode='lines+markers'
        ), row=1, col=1),
    fig.add_trace(go.Scatter(
        x=br1['Activation_x'], y=br1['avg_line'],
        line=dict(width=2.0, color='rgb(34, 178, 159)',dash='dot'),
         name = 'Avg. Exec Time',
        mode='lines+markers'
        ), row=1, col=1),

    

    br2 = df_cleaned3[df_cleaned3['trigger']=='trigger2'].reset_index()
    br2['avg_line'] = convert(br2['time_diff_cal'].mean(),0)
    br2.sort_values(by= 'Activation_x',inplace=True,ascending=True)

    fig.add_trace(go.Scatter(
        x=br2['Activation_x'], y=br2['time_diff'],
        line=dict(width=2.0, color='rgb(38, 127, 195)'),
#         name = 'T2 Exec Time',
        mode='lines+markers'
        ), row=2, col=1),
    fig.add_trace(go.Scatter(
        x=br2['Activation_x'], y=br2['avg_line'],
        line=dict(width=2.0, color='rgb(34, 178, 159)',dash='dot'),
#         name = 'Avg. T2 Exec Time',
        mode='lines+markers'
        ), row=2, col=1),    



    br3 = df_cleaned3[df_cleaned3['trigger']=='trigger3'].reset_index()
    br3['avg_line'] = convert(br3['time_diff_cal'].mean(),0)
    br3.sort_values(by= 'Activation_x',inplace=True,ascending=True)

    fig.add_trace(go.Scatter(
        x=br3['Activation_x'], y=br3['time_diff'],
        line=dict(width=2.0, color='rgb(93, 167, 223)'),
#         name = 'T3 Exec Time',
        mode='lines+markers'
        ), row=3, col=1),
    fig.add_trace(go.Scatter(
        x=br3['Activation_x'], y=br3['avg_line'],
        line=dict(width=2.0, color='rgb(34, 178, 159)',dash='dot'),
#         name = 'Avg. T3 Exec Time',
        mode='lines+markers'
        ), row=3, col=1),    

    br4 = df_cleaned3[df_cleaned3['trigger']=='trigger4'].reset_index()
    br4['avg_line'] = convert(br4['time_diff_cal'].mean(),0)
    br4.sort_values(by= 'Activation_x',inplace=True,ascending=True)

    fig.add_trace(go.Scatter(
        x=br4['Activation_x'],y=br4['time_diff'],
        line=dict(width=2.0, color='rgb(116, 187, 242)'),
        name = 'Runtime',
        mode='lines+markers'
        ), row=4, col=1),
    fig.add_trace(go.Scatter(
        x=br4['Activation_x'], y=br4['avg_line'],
        line=dict(width=2.0, color='rgb(34, 178, 159)',dash='dot'),
        name = 'Avg. Runtime',
        mode='lines+markers'
        ), row=4, col=1),    
    fig.update_layout(
    height=900, width=1000,showlegend=False
    )
    fig.show()

# %%
def plot2(Date_Range):
    df_n = pd.DataFrame()
    if (Date_Range == 'Last 1 Week'):
        df_n=df_cleaned3[df_cleaned3['Start time_x']>np.max(df_cleaned3['Start time_x'])-timedelta(7)]  
        graph2(df_n)
    elif(Date_Range == 'Last 2 Week'):    
        df_n=df_cleaned3[df_cleaned3['Start time_x']>np.max(df_cleaned3['Start time_x'])-timedelta(14)]
        graph2(df_n)
    elif(Date_Range == 'Last 3 Week'):
        df_n=df_cleaned3[df_cleaned3['Start time_x']>np.max(df_cleaned3['Start time_x'])-timedelta(21)]
        graph2(df_n)
    elif(Date_Range == 'Last 4 Week'):
        df_n=df_cleaned3[df_cleaned3['Start time_x']>np.max(df_cleaned3['Start time_x'])-timedelta(28)]
        graph2(df_n)

        
widgets.interact(plot2,Date_Range=['Last 4 Week','Last 3 Week','Last 2 Week','Last 1 Week']);
# Out:
# interactive(children=(Dropdown(description='Date_Range', options=('Last 4 Week', 'Last 3 Week', 'Last 2 Week',…

# %%
l = list()

for i in range(len(df3)):
    t = pd.Timedelta(df3['End_x'][i] - df3['Start time_x'][i]).seconds/60
    l.append(t)
    
df3['time_diff'] = l
df3['time_diff'] = df3['time_diff'].round(0)

# %%
df_grouped = df3.groupby(['Activation_x','TableName','trigger']).agg({'time_diff':'sum'}).reset_index()#[['trigger','TableName','Activation_x','time_diff']]
df_grouped['Activation_x'] = pd.to_datetime(df_grouped['Activation_x'])

# %% [markdown]
# # <div style="text-align: center">III. Trigger level Deep Dives</div>

# %%
global date_filter
date_filter=widgets.DatePicker(description='Select Date');
display(date_filter)
# Out:
# DatePicker(value=None, description='Select Date')

# %%
#df_grouped = df_grouped[df_grouped['Activation_x']==start_date_widget.value]
df_grouped =  df_grouped.rename(columns={"time_diff": "Execution Time", "Name_x": "Job Name"})

# %%
def graph3(df_n):
    df_n = df_n.sort_values(by='Execution Time',ascending = False).head(6)
    fig = px.bar(df_n, x='TableName', y='Execution Time',height = 500,width = 950)
    fig.show()

# %%
def plot3(Trigger):
    df_n = pd.DataFrame()
    if (Trigger == 'Trigger 1'):
        df_n=df_grouped[(df_grouped['trigger'] == 'trigger1')]
        df_n = df_n[df_n['Activation_x'] == date_filter.value] 
        #print(df_n)
        graph3(df_n)
    elif(Trigger == 'Trigger 2'):    
        df_n=df_grouped[df_grouped['trigger'] == 'trigger2']
        df_n = df_n[df_n['Activation_x'] == date_filter.value]  
        graph3(df_n)
    elif(Trigger == 'Trigger 3'):
        df_n=df_grouped[df_grouped['trigger'] == 'trigger3']   
        df_n = df_n[df_n['Activation_x'] == date_filter.value]  
        graph3(df_n)
    elif(Trigger == 'Trigger 4'):
        df_n=df_grouped[df_grouped['trigger'] == 'trigger4']
        df_n = df_n[df_n['Activation_x'] == date_filter.value]  
        graph3(df_n)

        
widgets.interact(plot3,Trigger=['Trigger 1','Trigger 2','Trigger 3','Trigger 4']);
# Out:
# interactive(children=(Dropdown(description='Trigger', options=('Trigger 1', 'Trigger 2', 'Trigger 3', 'Trigger…

# %% [markdown]
# # <div style="text-align: center">IV. Availability Trend of HROS Data</div>

# %%
df_run = df1

df_run['Activation'] = pd.to_datetime(df_run['Activation']).dt.strftime('%d-%b-%y')
df_run['Start time'] = pd.to_datetime(df_run['Start time'])
df_run['End'] = pd.to_datetime(df_run['End'])

df_run.reset_index(inplace=True)

df_run['start_time'] = df_run['Start time'].dt.date
#df1['end_time'] = df1['End'].dt.date
l = list()

for i in range(len(df_run)):
    s = str(df_run['start_time'][i]) + " 00:00:00"
    l.append(s)

df_run['start_time'] = l
df_run['start_time'] = pd.to_datetime(df_run['start_time'])


df_run['end_time'] = df_run['End'].dt.date
#df1['end_time'] = df1['End'].dt.date
l = list()

for i in range(len(df_run)):
    s = str(df_run['end_time'][i]) + " 00:00:00"
    l.append(s)

df_run['end_time'] = l
df_run['end_time'] = pd.to_datetime(df_run['end_time'])


l = list()

for i in range(len(df_run)):
    t = convert(pd.Timedelta(df_run['Start time'][i] - df_run['start_time'][i]).seconds,0)
    l.append(float(t))
    
df_run['start_td'] = l
df_run['start_td'] = df_run['start_td'].round(2)

###############################################################################################

l = list()

for i in range(len(df_run)):
    t = convert(pd.Timedelta(df_run['End'][i] - df_run['end_time'][i]).seconds,0)
    l.append(float(t))
    
df_run['end_td'] = l
df_run['end_td'] = df_run['end_td'].round(2)


l1 = list()
l2 = list()

for i in range(len(df_run)):
    t1 = convert(pd.Timedelta(df_run['End'][i] - df_run['Start time'][i]).seconds,0)
    t2 = pd.Timedelta(df_run['End'][i] - df_run['Start time'][i]).seconds
    l1.append(t1)
    l2.append(t2)
    
df_run['time_diff'] = l1
df_run['time_diff_cal'] = l2
df_run['time_diff_cal'] = df_run['time_diff_cal'].round(2)


df_run= df_run[['Activation','Start time','End','start_td','end_td','time_diff','time_diff_cal']]

# %%
def graph6(df_run):
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df_run['Activation'], y=df_run['end_td'],
        line=dict(width=2.0, color='rgb(131, 90, 241)'),#rgb(255, 127, 14)
        name = 'Daily Run Time',
        mode='lines+markers'
        ))
    fig.update_layout(
    xaxis_title="Load Date",
    yaxis_title="Job Completion Time (in hr.min)",
    
     titlefont=dict(
        size=20,
        #color="#7f7f7f",
        ),
        title={
        'text': "Daily Trend of Producton Jobs runtime",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
         xaxis=dict(showticklabels=True, automargin=True,autorange="reversed")
    )
    fig.show()

# %%
def plot6(Date_Range):
    df_n = pd.DataFrame()
    if (Date_Range == 'Last 1 Week'):
        df_n=df_run[df_run['Start time']>np.max(df_run['Start time'])-timedelta(7)]  
        graph6(df_n)
    elif(Date_Range == 'Last 2 Week'):    
        df_n=df_run[df_run['Start time']>np.max(df_run['Start time'])-timedelta(14)]
        graph6(df_n)
    elif(Date_Range == 'Last 3 Week'):
        df_n=df_run[df_run['Start time']>np.max(df_run['Start time'])-timedelta(21)]
        graph6(df_n)
    elif(Date_Range == 'Last 4 Week'):
        df_n=df_run[df_run['Start time']>np.max(df_run['Start time'])-timedelta(28)]
        graph6(df_n)

        
widgets.interact(plot6,Date_Range=['Last 4 Week','Last 3 Week','Last 2 Week','Last 1 Week']);
# Out:
# interactive(children=(Dropdown(description='Date_Range', options=('Last 4 Week', 'Last 3 Week', 'Last 2 Week',…

# %%
df2['Activation'] = pd.to_datetime(df2['Activation']).dt.strftime('%Y-%m-%d')
df_cleaned2 = df2

# %%
df_cleaned2['Start time'] = pd.to_datetime(df_cleaned2['Start time'])
df_cleaned2['End'] = pd.to_datetime(df_cleaned2['End'])
df_cleaned2.reset_index(inplace=True)
#df_cleaned2 = df_cleaned2.dropna(subset=['Start time']).reset_index()

# %%
l = list()

for i in range(len(df_cleaned2)):
    t = pd.Timedelta(df_cleaned2['End'][i] - df_cleaned2['Start time'][i]).seconds/60
    l.append(t)
    
df_cleaned2['time_diff'] = l
df_cleaned2['time_diff'] = df_cleaned2['time_diff'].round(0)

# %%
df_cleaned2 = df_cleaned2[['TableName','Activation','Start time','End','time_diff','Error_Flag','Runtime']]
#df_cleaned2.head()

# %%
df_cleaned2 = df_cleaned2[df_cleaned2['Error_Flag']==1]

# %%
d1 = df_cleaned2.groupby(['TableName'])['TableName'].count().reset_index(name = 'Failure')
d2 = df_cleaned2.groupby(['TableName'])['time_diff'].sum().reset_index(name = 'Total Time Taken')

# %%
df_merged = pd.merge(d1,d2,on='TableName')

# %% [markdown]
# # <div style="text-align: center">V. View into Failed Jobs</div>

# %%
def graph4(df_n):
    fig = px.scatter(df_n, x="Total Time Taken", y="Failure",
                  hover_name="TableName",size="Failure",
                 color="TableName",width= 1000,height = 400,
                  size_max=30)
    fig.update_layout(
                      xaxis_title="Runtime(in mins.)",
                      yaxis_title="#Failures",
                   titlefont=dict(
                        size=20
                                  ),
                      title={
                          'text': "Failed Jobs Summary",
                           'y':0.9,
                           'x':0.5,
                           'xanchor': 'center',
                           'yanchor': 'top'},
                      xaxis=dict(showticklabels=True, automargin=True)
                      )
    fig.show()

# %%
def plot4(Failure):
    df_n = pd.DataFrame()
    if (Failure == 'Failed less than 3'):
        df_n=df_merged[df_merged['Failure'] <3]   
        graph4(df_n)
    elif(Failure == 'Failed less than 5'):    
        df_n=df_merged[(df_merged['Failure'] >= 3) & (df_merged['Failure'] < 5)]  
        graph4(df_n)
    elif(Failure == 'Failed greater than 5'):
        df_n=df_merged[df_merged['Failure'] >= 5] 
        graph4(df_n) 
    else:
        df_n = df_merged
        graph4(df_n)
        
widgets.interact(plot4,Failure=['Failed less than 3','Failed less than 5','Failed greater than 5','All']);
# Out:
# interactive(children=(Dropdown(description='Failure', options=('Failed less than 3', 'Failed less than 5', 'Fa…

# %%
df_top_failed = df_merged.sort_values(by="Failure",ascending=False)
df_top_failed = df_top_failed[df_top_failed['Failure']>5]['TableName']

# %%
df_top_failed = pd.merge(df_top_failed,df_cleaned2,on='TableName')

# %%
df_top_failed.sort_values(by='time_diff',ascending=False,inplace=True)

# %% [markdown]
# # <div style="text-align: center">VI. Table Failed showing Date and Execution Time</div>

# %%
def graph5(df):
    fig = go.Figure(data=[go.Table(
    header=dict(values=['Table Name', 'Start Time','End Time','Run Time(in min.)']),
    cells=dict(values=[df['TableName'],df['Start time'].dt.strftime('%d-%b-%y %r'),df['End'].dt.strftime('%d-%b-%y %r'),df['time_diff'].round(0)], # 2nd column
               line_color='darkslategray',
               fill_color='lightcyan',
               align='left'))
    ])

    fig.show()

# %%
def plot5(Trigger):
    df_n = pd.DataFrame()
    if (Trigger == 'Top 5'):
        df_n=df_top_failed.head(5)  
        graph5(df_n)
    elif(Trigger == 'Top 10'):    
        df_n=df_top_failed.head(10)
        graph5(df_n)
    elif(Trigger == 'Top 15'):
        df_n=df_top_failed.head(15)   
        graph5(df_n)


        
widgets.interact(plot5,Trigger=['Top 5','Top 10','Top 15']);
# Out:
# interactive(children=(Dropdown(description='Trigger', options=('Top 5', 'Top 10', 'Top 15'), value='Top 5'), O…
